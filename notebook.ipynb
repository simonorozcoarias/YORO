# %%
import numpy as np
import pandas as pd
import os
import subprocess
from track_memory import track_memory_use, plot_memory_use

# %%
# using a function so we can track memory usage
@track_memory_use(close=False, return_history=True)
def memmory_consume(filename:str):
    
    command = f'python pipelineDomain.py -f {filename} -o test/testing.tab'
    subprocess.run(command,shell=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE)

# %%
_,_ = memmory_consume(filename='test/TEx3.fasta')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Current memory usage: 6.992267
# Peak memory usage: 7.003076

# %%
import pandas as pd
data = pd.read_csv('genomes_links_final_final.csv',sep=';')
data.head(40)
# Out:
#            Order          Family                  Species  \
# 0        Fagales    Juglandaceae            Juglans nigra
# 1        Fagales    Juglandaceae       Juglans microcarpa
# 2        Fagales    Juglandaceae        Juglans sigillata
# 3        Fagales    Juglandaceae            Juglans regia
# 4        Fagales    Juglandaceae      Juglans cathayensis
# 5        Fagales    Juglandaceae    Pterocarya stenoptera
# 6        Fagales   Casuarinaceae         Casuarina glauca
# 7   Cucurbitales   Cucurbitaceae      Lagenaria siceraria
# 8   Cucurbitales   Cucurbitaceae     Siraitia grosvenorii
# 9   Cucurbitales   Cucurbitaceae      Momordica charantia
# 10  Cucurbitales     Datiscaceae        Datisca glomerata
# 11       Rosales        Rosaceae              Prunus mume
# 12       Rosales        Rosaceae           Rosa chinensis
# 13       Rosales        Rosaceae          Rosa multiflora
# 14       Rosales        Rosaceae     Potentilla micrantha
# ...
